# %% [markdown]
# <a href="https://colab.research.google.com/github/thejakunam/Machine-Learning/blob/master/ML_Lab_XGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt")

X = dataset.iloc[:, [0, 3]]
y = dataset.iloc[:, 4]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
import xgboost
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
#tuning parameters for XGB classifier
tuned_parameters = [{'learning_rate':[0.1,0.5,1.0],'n_estimators':[100,200,300],'booster':['gbtree', 'gblinear', 'dart'],'max_delta_step':[0,10,100]}]

scores = ['precision', 'recall','f1']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import xgboost
from xgboost import XGBClassifier
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(XGBClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'n_estimators': 200}
#
# Grid scores on development set:
#
# 0.891 (+/-0.033) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'n_estimators': 100}
# 0.891 (+/-0.021) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'n_estimators': 200}
# 0.888 (+/-0.023) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 0, 'n_estimators': 300}
# 0.891 (+/-0.033) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 10, 'n_estimators': 100}
# 0.891 (+/-0.021) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 10, 'n_estimators': 200}
# 0.888 (+/-0.023) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 10, 'n_estimators': 300}
# 0.891 (+/-0.033) for {'booster': 'gbtree', 'learning_rate': 0.1, 'max_delta_step': 100, 'n_estimators': 100}
# ...
