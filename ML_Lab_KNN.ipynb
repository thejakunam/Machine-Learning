# %% [markdown]
# <a href="https://colab.research.google.com/github/thejakunam/Machine-Learning/blob/master/ML_Lab_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt")

X = dataset.iloc[:, [0, 3]]
y = dataset.iloc[:, 4]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
#tuning parameters for Logistic Regression
tuned_parameters = [{'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'], 'n_neighbors':[3,5,7],'p':[1,2],'weights':['uniform','distance']}]

scores = ['precision', 'recall','f1']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'algorithm': 'auto', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.885 (+/-0.019) for {'algorithm': 'auto', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.891 (+/-0.028) for {'algorithm': 'auto', 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.886 (+/-0.019) for {'algorithm': 'auto', 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.892 (+/-0.028) for {'algorithm': 'auto', 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.895 (+/-0.015) for {'algorithm': 'auto', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.898 (+/-0.027) for {'algorithm': 'auto', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.893 (+/-0.023) for {'algorithm': 'auto', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.901 (+/-0.027) for {'algorithm': 'auto', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# ...
